# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

os.chdir('..')

from design_space_exploration.dse import template_to_system, read_architecture_template
from software_model.utils import Tensor, DataType, data_type_dict
from software_model.matmul import Matmul

# %%
size = 4096
T = 131135 + 6193
k = 12288
x = np.arange(1,size)
y = np.floor(k / x)
remain_x = k % x
z = x * y * T
w = z + remain_x * T
plt.plot(x, y, label='y vs x')
plt.plot(x, z, label='z vs x')
plt.plot(x, w, label='w vs x')
plt.xlabel('x')
plt.ylabel('Value')
plt.title('Plot of y vs x and z vs x')
plt.legend()
plt.show()
x, y, z
# Out:
# (array([   1,    2,    3, ..., 4093, 4094, 4095]),
#  array([1.2288e+04, 6.1440e+03, 4.0960e+03, ..., 3.0000e+00, 3.0000e+00,
#         3.0000e+00]),
#  array([1.68748646e+09, 1.68748646e+09, 1.68748646e+09, ...,
#         1.68625051e+09, 1.68666250e+09, 1.68707448e+09]))

# %%
simdram_spec = read_architecture_template("configs/SIMDRAM_STD.json")
simdram_sys = template_to_system(simdram_spec)

#setup tensor size
M = 1
K = 12288
# N = 1024
gemv_latency = []
gemm_latency = []
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 simdram_spec = read_architecture_template("configs/SIMDRAM_STD.json")
#       2 simdram_sys = template_to_system(simdram_spec)
#       4 #setup tensor size
#
# File ~/Desktop/LLMCompass/design_space_exploration/dse.py:32, in read_architecture_template(file_path)
#      31 def read_architecture_template(file_path):
# ---> 32     with open(file_path, "r") as f:
#      33         arch_specs = json.load(f)
#      34     return arch_specs
#
# FileNotFoundError: [Errno 2] No such file or directory: 'configs/SIMDRAM_STD.json'
